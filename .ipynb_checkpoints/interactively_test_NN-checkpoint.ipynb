# %%
import sys
import h5py
import numpy as np
import healpy as hp
import tensorflow as tf
import random as python_random
import nnhealpix.layers
from tensorflow.keras import metrics
import pandas as pd
from loss_functions import sigma_loss, sigma2_loss,sigma_batch_loss,sigma_norm_loss,sigma_log_loss,mse_tau,mse_sigma, mse_batch, sigma_f_loss
import math
import useful_functions as uf
import NN_functions as nuf
import os, shutil

seed_train=40
np.random.seed(seed_train)# i set a random seed for the generation of the maps for reproducibility
tf.random.set_seed(seed_train)#the seed for tensorflow operation is different from the seed for numpy operations

#map gen
nside = 16
n_train=200 #the total number of training+validation pair of maps that i will generate
n_train_fix=200 #the total number of of training maps i will spread on all the r interval -> for each r value i generate n_train_fix/len(r) maps 
kind_of_map="BB"
n_channels=2
pol=1
res=hp.nside2resol(nside, arcmin=False) 
sensitivity=4

reduce_lr_on_plateau = True
p_stopping=20
p_reduce=5
f_reduce=0.5
stopping_monitor="val_loss"
reduce_monitor="val_loss"
metrics=[]
base_dir="None"

#network structure
one_layer=True # this is to switch between one dense layer or two dense layer
drop=[0.2,0.2,0.2]
use_drop=[False,False,False]
use_normalization=[False,True,True]
n_layers=2
nodes_per_layer=[64, 64, 128]
if kind_of_map!="QU": 
    n_inputs=n_channels
else:
    n_inputs=pol*n_channels
n_output=1
kernel_initializer="glorot_uniform"#"he_normal"
n_optimizer=0
activation_dense="relu"#"swish"#"relu"

#train and val
batch_size = 16
max_epochs = 100
lr=0.0001
fval=0.1 # this is the fraction of data that i use for validation, computed on n_train_fix
training_loss="mse"
loss_training=tf.keras.losses.MeanSquaredError() # this is the loss i use for the training
shuffle=True
norm=True
map_norm=True
batch_ordering=False #True
distr=1

f_ = np.load('/home/amorelli/cl_generator/outfile_R_000_001_seed=67.npz') 
#print("outfile_R:",f_.files) #give the keiwords for the stored arrays
labels=f_.files
data=f_[labels[0]]
r=f_[labels[1]]
r, data=uf.unison_sorted_copies(r, data)
indexes=np.linspace(0,len(r)-1,10,dtype=int)
r=r[indexes]
data=data[indexes]

#input_folder="/home/amorelli/foreground_noise_maps/noise_generation"
#input_files=os.listdir(input_folder)
#for i in range(len(input_files)):
   # input_files[i]=input_folder+"/"+input_files[i]
noise_maps=uf.generate_noise_maps(n_train,n_channels,nside,pol=1,sensitivity=sensitivity,input_files=None)

#noise_E,noise_B=uf.convert_to_EB(noise_maps)

maps_per_cl_gen=uf.maps_per_cl(distribution=distr)
maps_per_cl=maps_per_cl_gen.compute_maps_per_cl(r,n_train,n_train_fix)

mappe_B,y_r=uf.generate_maps(data, r,n_train=n_train,nside=nside, map_per_cl=maps_per_cl, 
                             noise_maps=noise_maps, beam_w=2*res, kind_of_map=kind_of_map, 
                             raw=0 , n_channels=n_channels,beam_yes=1 , verbose=0)


x_train,y_train,x_val,y_val = nuf.prepare_data(y_r,mappe_B,r,n_train,n_train_fix,fval,maps_per_cl
                                               , batch_size, batch_ordering=batch_ordering)

if norm:
    y_train=nuf.normalize_data(y_train,r)
    y_val=nuf.normalize_data(y_val,r)

if map_norm:
    for i in range(len(x_train)):
        for j in range(n_inputs):
            x=x_train[i,:,j]
            x_train[i,:,j]=nuf.normalize_data(x,x)
    for i in range(len(x_val)):
        for j in range(n_inputs):
            x=x_val[i,:,j]
            x_val[i,:,j]=nuf.normalize_data(x,x)

model=nuf.build_network(n_inputs,nside,n_layers=n_layers,layer_nodes=nodes_per_layer,num_output=n_output,
                        use_normalization=use_normalization,use_drop=use_drop,
                        drop=drop,activation_dense=activation_dense,kernel_initializer=kernel_initializer)
#print(model.summary())

history=nuf.compile_and_fit(model, x_train, y_train, x_val, y_val, batch_size, max_epochs, 
                            stopping_monitor,p_stopping,reduce_monitor,f_reduce, p_reduce,base_dir, loss_training,lr,
                            metrics,shuffle=shuffle,verbose=2,
                            callbacks=[False,False,False,False,False],append=False,n_optimizer=n_optimizer)
#[early_stopping,reduce_lr,csv_logger,model_checkpoint_callback,increase_lr]

predictions_train=model.predict(x_train)

predictions_val=model.predict(x_val)
# Out:
# 2023-06-24 13:18:59.678263: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-24 13:19:00.888730: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-06-24 13:19:00.888858: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-06-24 13:19:00.888875: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-06-24 13:19:02.895651: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-06-24 13:19:02.895755: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (coka.fe.infn.it): /proc/driver/nvidia/version does not exist
# 2023-06-24 13:19:02.897101: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/100
# 11/11 - 6s - loss: 1.8935 - val_loss: 0.9994 - 6s/epoch - 527ms/step
# Epoch 2/100
# 11/11 - 1s - loss: 1.2030 - val_loss: 0.9899 - 567ms/epoch - 52ms/step
# Epoch 3/100
# 11/11 - 1s - loss: 0.9057 - val_loss: 0.9709 - 664ms/epoch - 60ms/step
# Epoch 4/100
# 11/11 - 1s - loss: 0.6791 - val_loss: 0.9580 - 686ms/epoch - 62ms/step
# Epoch 5/100
# 11/11 - 1s - loss: 0.5543 - val_loss: 0.9455 - 681ms/epoch - 62ms/step
# Epoch 6/100
# 11/11 - 1s - loss: 0.5533 - val_loss: 0.9416 - 596ms/epoch - 54ms/step
# Epoch 7/100
# 11/11 - 1s - loss: 0.4278 - val_loss: 0.9339 - 609ms/epoch - 55ms/step
# Epoch 8/100
# 11/11 - 1s - loss: 0.3531 - val_loss: 0.9193 - 590ms/epoch - 54ms/step
# Epoch 9/100
# 11/11 - 1s - loss: 0.3945 - val_loss: 0.9030 - 572ms/epoch - 52ms/step
# Epoch 10/100
# 11/11 - 1s - loss: 0.2980 - val_loss: 0.8813 - 530ms/epoch - 48ms/step
# Epoch 11/100
# 11/11 - 1s - loss: 0.3066 - val_loss: 0.8508 - 591ms/epoch - 54ms/step
# Epoch 12/100
# 11/11 - 1s - loss: 0.2538 - val_loss: 0.8123 - 580ms/epoch - 53ms/step
# Epoch 13/100
# 11/11 - 1s - loss: 0.2482 - val_loss: 0.7665 - 573ms/epoch - 52ms/step
# Epoch 14/100
# 11/11 - 1s - loss: 0.2199 - val_loss: 0.7305 - 556ms/epoch - 51ms/step
# Epoch 15/100
# 11/11 - 1s - loss: 0.1966 - val_loss: 0.7060 - 549ms/epoch - 50ms/step
# Epoch 16/100
# 11/11 - 1s - loss: 0.2137 - val_loss: 0.6861 - 545ms/epoch - 50ms/step
# Epoch 17/100
# 11/11 - 1s - loss: 0.1744 - val_loss: 0.6546 - 542ms/epoch - 49ms/step
# Epoch 18/100
# 11/11 - 1s - loss: 0.1797 - val_loss: 0.6129 - 554ms/epoch - 50ms/step
# Epoch 19/100
# 11/11 - 1s - loss: 0.2193 - val_loss: 0.5991 - 552ms/epoch - 50ms/step
# Epoch 20/100
# 11/11 - 1s - loss: 0.1601 - val_loss: 0.5892 - 581ms/epoch - 53ms/step
# Epoch 21/100
# 11/11 - 1s - loss: 0.1944 - val_loss: 0.5693 - 571ms/epoch - 52ms/step
# Epoch 22/100
# 11/11 - 1s - loss: 0.2048 - val_loss: 0.5639 - 545ms/epoch - 50ms/step
# Epoch 23/100
# 11/11 - 1s - loss: 0.1867 - val_loss: 0.5508 - 555ms/epoch - 50ms/step
# Epoch 24/100
# 11/11 - 1s - loss: 0.1505 - val_loss: 0.5321 - 532ms/epoch - 48ms/step
# Epoch 25/100
# 11/11 - 1s - loss: 0.1354 - val_loss: 0.5242 - 550ms/epoch - 50ms/step
# Epoch 26/100
# 11/11 - 1s - loss: 0.1617 - val_loss: 0.5119 - 586ms/epoch - 53ms/step
# Epoch 27/100
# 11/11 - 1s - loss: 0.1731 - val_loss: 0.5582 - 561ms/epoch - 51ms/step
# Epoch 28/100
# 11/11 - 1s - loss: 0.1539 - val_loss: 0.5787 - 553ms/epoch - 50ms/step
# Epoch 29/100
# 11/11 - 1s - loss: 0.1333 - val_loss: 0.5704 - 566ms/epoch - 51ms/step
# Epoch 30/100
# 11/11 - 1s - loss: 0.1596 - val_loss: 0.5687 - 548ms/epoch - 50ms/step
# Epoch 31/100
# 11/11 - 1s - loss: 0.1453 - val_loss: 0.5501 - 565ms/epoch - 51ms/step
# Epoch 32/100
# 11/11 - 1s - loss: 0.1188 - val_loss: 0.6209 - 589ms/epoch - 54ms/step
# Epoch 33/100
# 11/11 - 1s - loss: 0.1538 - val_loss: 0.6249 - 549ms/epoch - 50ms/step
# Epoch 34/100
# 11/11 - 1s - loss: 0.1485 - val_loss: 0.5601 - 555ms/epoch - 50ms/step
# Epoch 35/100
# 11/11 - 1s - loss: 0.1440 - val_loss: 0.5377 - 556ms/epoch - 51ms/step
# Epoch 36/100
# 11/11 - 1s - loss: 0.1643 - val_loss: 0.5476 - 554ms/epoch - 50ms/step
# Epoch 37/100
# 11/11 - 1s - loss: 0.1535 - val_loss: 0.6150 - 575ms/epoch - 52ms/step
# Epoch 38/100
# 11/11 - 1s - loss: 0.1624 - val_loss: 0.6591 - 600ms/epoch - 55ms/step
# Epoch 39/100
# 11/11 - 1s - loss: 0.1526 - val_loss: 0.6464 - 567ms/epoch - 52ms/step
# Epoch 40/100
# 11/11 - 1s - loss: 0.1464 - val_loss: 0.6368 - 568ms/epoch - 52ms/step
# Epoch 41/100
# 11/11 - 1s - loss: 0.1002 - val_loss: 0.6051 - 568ms/epoch - 52ms/step
# Epoch 42/100
# 11/11 - 1s - loss: 0.1087 - val_loss: 0.5670 - 584ms/epoch - 53ms/step
# Epoch 43/100
# 11/11 - 1s - loss: 0.1050 - val_loss: 0.5609 - 573ms/epoch - 52ms/step
# Epoch 44/100
# 11/11 - 1s - loss: 0.1670 - val_loss: 0.5462 - 580ms/epoch - 53ms/step
# Epoch 45/100
# 11/11 - 1s - loss: 0.1217 - val_loss: 0.5002 - 557ms/epoch - 51ms/step
# Epoch 46/100
# 11/11 - 1s - loss: 0.1465 - val_loss: 0.4893 - 570ms/epoch - 52ms/step
# Epoch 47/100
# 11/11 - 1s - loss: 0.1319 - val_loss: 0.4546 - 560ms/epoch - 51ms/step
# Epoch 48/100
# 11/11 - 1s - loss: 0.1612 - val_loss: 0.4359 - 564ms/epoch - 51ms/step
# Epoch 49/100
# 11/11 - 1s - loss: 0.1696 - val_loss: 0.4109 - 560ms/epoch - 51ms/step
# Epoch 50/100
# 11/11 - 1s - loss: 0.1058 - val_loss: 0.4377 - 580ms/epoch - 53ms/step
# Epoch 51/100
# 11/11 - 1s - loss: 0.1111 - val_loss: 0.4721 - 586ms/epoch - 53ms/step
# Epoch 52/100
# 11/11 - 1s - loss: 0.1124 - val_loss: 0.4570 - 552ms/epoch - 50ms/step
# Epoch 53/100
# 11/11 - 1s - loss: 0.1418 - val_loss: 0.4197 - 559ms/epoch - 51ms/step
# Epoch 54/100
# 11/11 - 1s - loss: 0.1743 - val_loss: 0.4804 - 579ms/epoch - 53ms/step
# Epoch 55/100
# 11/11 - 1s - loss: 0.1252 - val_loss: 0.4764 - 580ms/epoch - 53ms/step
# Epoch 56/100
# 11/11 - 1s - loss: 0.1041 - val_loss: 0.4702 - 575ms/epoch - 52ms/step
# Epoch 57/100
# 11/11 - 1s - loss: 0.1690 - val_loss: 0.5756 - 570ms/epoch - 52ms/step
# Epoch 58/100
# 11/11 - 1s - loss: 0.1336 - val_loss: 0.6116 - 566ms/epoch - 51ms/step
# Epoch 59/100
# 11/11 - 1s - loss: 0.1003 - val_loss: 0.5016 - 567ms/epoch - 52ms/step
# Epoch 60/100
# 11/11 - 1s - loss: 0.1052 - val_loss: 0.4609 - 581ms/epoch - 53ms/step
# Epoch 61/100
# 11/11 - 1s - loss: 0.1068 - val_loss: 0.4590 - 572ms/epoch - 52ms/step
# Epoch 62/100
# 11/11 - 1s - loss: 0.1111 - val_loss: 0.4293 - 565ms/epoch - 51ms/step
# Epoch 63/100
# 11/11 - 1s - loss: 0.1387 - val_loss: 0.4290 - 572ms/epoch - 52ms/step
# Epoch 64/100
# 11/11 - 1s - loss: 0.1167 - val_loss: 0.4371 - 556ms/epoch - 51ms/step
# Epoch 65/100
# 11/11 - 1s - loss: 0.1372 - val_loss: 0.4781 - 580ms/epoch - 53ms/step
# Epoch 66/100
# 11/11 - 1s - loss: 0.1061 - val_loss: 0.4776 - 561ms/epoch - 51ms/step
# Epoch 67/100
# 11/11 - 1s - loss: 0.1024 - val_loss: 0.4561 - 596ms/epoch - 54ms/step
# Epoch 68/100
# 11/11 - 1s - loss: 0.1044 - val_loss: 0.4758 - 594ms/epoch - 54ms/step
# Epoch 69/100
# 11/11 - 1s - loss: 0.0952 - val_loss: 0.4880 - 564ms/epoch - 51ms/step
# Epoch 70/100
# 11/11 - 1s - loss: 0.1627 - val_loss: 0.4667 - 553ms/epoch - 50ms/step
# Epoch 71/100
# 11/11 - 1s - loss: 0.1062 - val_loss: 0.4508 - 566ms/epoch - 51ms/step
# Epoch 72/100
# 11/11 - 1s - loss: 0.1268 - val_loss: 0.4356 - 573ms/epoch - 52ms/step
# Epoch 73/100
# 11/11 - 1s - loss: 0.1128 - val_loss: 0.4505 - 570ms/epoch - 52ms/step
# Epoch 74/100
# 11/11 - 1s - loss: 0.1070 - val_loss: 0.4463 - 622ms/epoch - 57ms/step
# Epoch 75/100
# 11/11 - 1s - loss: 0.1303 - val_loss: 0.4379 - 594ms/epoch - 54ms/step
# Epoch 76/100
# 11/11 - 1s - loss: 0.1018 - val_loss: 0.4263 - 571ms/epoch - 52ms/step
# Epoch 77/100
# 11/11 - 1s - loss: 0.0877 - val_loss: 0.4332 - 574ms/epoch - 52ms/step
# Epoch 78/100
# 11/11 - 1s - loss: 0.1056 - val_loss: 0.4415 - 564ms/epoch - 51ms/step
# Epoch 79/100
# 11/11 - 1s - loss: 0.0837 - val_loss: 0.4522 - 580ms/epoch - 53ms/step
# Epoch 80/100
# 11/11 - 1s - loss: 0.1115 - val_loss: 0.5170 - 578ms/epoch - 53ms/step
# Epoch 81/100
# 11/11 - 1s - loss: 0.0937 - val_loss: 0.5176 - 612ms/epoch - 56ms/step
# Epoch 82/100
# 11/11 - 1s - loss: 0.1220 - val_loss: 0.5014 - 602ms/epoch - 55ms/step
# Epoch 83/100
# 11/11 - 1s - loss: 0.0944 - val_loss: 0.5236 - 596ms/epoch - 54ms/step
# Epoch 84/100
# 11/11 - 1s - loss: 0.1479 - val_loss: 0.5953 - 581ms/epoch - 53ms/step
# Epoch 85/100
# 11/11 - 1s - loss: 0.1249 - val_loss: 0.5832 - 614ms/epoch - 56ms/step
# Epoch 86/100
# 11/11 - 1s - loss: 0.1064 - val_loss: 0.5860 - 573ms/epoch - 52ms/step
# Epoch 87/100
# 11/11 - 1s - loss: 0.1429 - val_loss: 0.5829 - 577ms/epoch - 52ms/step
# Epoch 88/100
# 11/11 - 1s - loss: 0.0802 - val_loss: 0.5754 - 591ms/epoch - 54ms/step
# Epoch 89/100
# 11/11 - 1s - loss: 0.1059 - val_loss: 0.5316 - 583ms/epoch - 53ms/step
# Epoch 90/100
# 11/11 - 1s - loss: 0.1486 - val_loss: 0.5207 - 567ms/epoch - 52ms/step
# Epoch 91/100
# 11/11 - 1s - loss: 0.1059 - val_loss: 0.5392 - 587ms/epoch - 53ms/step
# Epoch 92/100
# 11/11 - 1s - loss: 0.1021 - val_loss: 0.5345 - 580ms/epoch - 53ms/step
# Epoch 93/100
# 11/11 - 1s - loss: 0.0968 - val_loss: 0.4942 - 560ms/epoch - 51ms/step
# Epoch 94/100
# 11/11 - 1s - loss: 0.1036 - val_loss: 0.5226 - 569ms/epoch - 52ms/step
# Epoch 95/100
# 11/11 - 1s - loss: 0.0909 - val_loss: 0.5190 - 625ms/epoch - 57ms/step
# Epoch 96/100
# 11/11 - 1s - loss: 0.1095 - val_loss: 0.4868 - 585ms/epoch - 53ms/step
# Epoch 97/100
# 11/11 - 1s - loss: 0.0984 - val_loss: 0.4720 - 594ms/epoch - 54ms/step
# Epoch 98/100
# 11/11 - 1s - loss: 0.0803 - val_loss: 0.4711 - 573ms/epoch - 52ms/step
# Epoch 99/100
# 11/11 - 1s - loss: 0.1035 - val_loss: 0.4832 - 610ms/epoch - 55ms/step
# Epoch 100/100
# 11/11 - 1s - loss: 0.1170 - val_loss: 0.4874 - 596ms/epoch - 54ms/step
# 6/6 [==============================] - 1s 21ms/step
# 1/1 [==============================] - 0s 48ms/step

# %%
import matplotlib.pyplot as plt
history_d=history.history
print(history_d.keys()) 
epochs=range(len(history_d["loss"]))
plt.plot(epochs,history_d["loss"])
plt.plot(epochs,history_d["val_loss"])
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
running=pd.DataFrame(history_d).rolling(window=5).mean()
plt.plot(epochs,running["loss"])
plt.plot(epochs,running["val_loss"])
print(np.min(running["val_loss"]))
print(running["val_loss"].idxmin())
# Out:
# 0.43700437545776366
# 77

# %%
predictions_train=nuf.denormalize_data(predictions_train,r)
predictions_val=nuf.denormalize_data(predictions_val,r)
y_train=nuf.denormalize_data(y_train,r)
y_val=nuf.denormalize_data(y_val,r)
plt.plot(y_train,predictions_train,linestyle='None',marker='.', markersize = 5.0,color="red")

# %%
y_count,y_red=uf.check_y(y_train)
pred_average=uf.running_average(predictions_train,y_count,y_red)

# %%
plt.plot(y_red,pred_average,linestyle='None',marker='.', markersize = 5.0,color="red")
plt.plot(y_red,y_red,color="blue")

# %%
plt.plot(range(len(predictions_train)),predictions_train-y_train)
#print(y_train)

# %%
plt.plot(predictions_val,y_val,linestyle='None',marker='.', markersize = 5.0,color="red")
plt.plot(y_val,y_val,color="blue")

# %%
plt.plot(range(len(predictions_val)),predictions_val-y_val)
