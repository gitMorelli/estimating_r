# %%
import sys
import h5py
import numpy as np
import healpy as hp
import tensorflow as tf
import random as python_random
import nnhealpix.layers
from tensorflow.keras import metrics
import pandas as pd
from loss_functions import sigma_loss, sigma2_loss,sigma_batch_loss,sigma_norm_loss,sigma_log_loss,mse_tau,mse_sigma, mse_batch, sigma_f_loss
import math
import useful_functions as uf
import NN_functions as nuf
import os, shutil
import keras_tuner

base_dir="/home/amorelli/r_estimate/B_maps_white_noise/tuning/25_6_23"
parameters={
    "lr":[0.01 * (0.1)**i for i in range(5)],
    "kernel":["he_normal","glorot_uniform"],
    "optimizers":[0,1],
    "use_normalization":[True,False],
    "drop":[0.2,0.5],
    "distr":[0,1],
    "activation":["relu","swish"]
}
n_param=len(parameters)
all_configurations=[]
def select_indices(n_param, parameters, configuration, depth):
    key=list(parameters.keys())[depth]
    dim=len(parameters[key])
    if depth==n_param-1:
        for i in range(dim):
            configuration[depth]=i
            all_configurations.append(list(configuration))
        #print(all_configurations)
        return None
    else:
        for i in range(dim):
            configuration[depth]=i
            select_indices(n_param, parameters, configuration, depth+1)
select_indices(n_param, parameters, [0 for i in range(n_param)],0)
# Out:
# 2023-06-26 21:19:39.860800: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-26 21:19:41.117123: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-06-26 21:19:41.117251: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-06-26 21:19:41.117268: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
with open(base_dir+"/"+'history_copy.txt',"r") as f:
    lines = f.readlines()

# %%
for i,l in enumerate(lines):
    lines[i]=l[:-2]
#print(lines)

# %%
def convert_to_dictionary(index,parameters):
    configuration=all_configurations[index]
    keys=list(parameters.keys())
    lista=[]
    for i,key in enumerate(keys):
        lista.append(parameters[key][configuration[i]])
    return lista

# %%
columns=list(parameters.keys())
columns.append("val_loss")
print(columns)
d={}
for c in columns:
    d[c]=[]
# Out:
# ['lr', 'kernel', 'optimizers', 'use_normalization', 'drop', 'distr', 'activation', 'val_loss']

# %%
print(d["kernel"])
for i,l in enumerate(lines[1:]):
    words=l.split(" ")
    index=int(words[0])
    val_loss=float(words[1])
    lista=convert_to_dictionary(index,parameters)
    lista.append(val_loss)
    for j,c in enumerate(columns):
        d[c].append(lista[j])
# Out:
# []

# %%
#print(d)
results=pd.DataFrame(d)
print(results.head())
# Out:
#      lr     kernel  optimizers  use_normalization  drop  distr activation  \
# 0  0.01  he_normal           0               True   0.2      0       relu
# 1  0.01  he_normal           0               True   0.2      0      swish
# 2  0.01  he_normal           0               True   0.2      1       relu
# 3  0.01  he_normal           0               True   0.2      1      swish
# 4  0.01  he_normal           0               True   0.5      0       relu
#
#    val_loss
# 0  0.162042
# 1  0.307463
# 2  0.405418
# 3  1.028196
# 4  0.401054

# %%
results=results.sort_values('val_loss')
print(results.head(10))
# Out:
#         lr          kernel  optimizers  use_normalization  drop  distr  \
# 94   0.001       he_normal           1              False   0.5      1
# 17   0.010       he_normal           1               True   0.2      0
# 51   0.010  glorot_uniform           1               True   0.2      1
# 59   0.010  glorot_uniform           1              False   0.2      1
# 76   0.001       he_normal           0              False   0.5      0
# 93   0.001       he_normal           1              False   0.5      0
# 26   0.010       he_normal           1              False   0.2      1
# 78   0.001       he_normal           0              False   0.5      1
# 105  0.001  glorot_uniform           0              False   0.2      0
# 73   0.001       he_normal           0              False   0.2      0
#
#     activation  val_loss
# 94        relu  0.108489
# 17       swish  0.115384
# 51       swish  0.119979
# 59       swish  0.120381
# 76        relu  0.125446
# 93       swish  0.125470
# 26        relu  0.125811
# 78        relu  0.125987
# 105      swish  0.126442
# 73       swish  0.131571

# %%
datatypes = results.dtypes
print(datatypes)
# Out:
# lr                   float64
# kernel                object
# optimizers             int64
# use_normalization       bool
# drop                 float64
# distr                  int64
# activation            object
# val_loss             float64
# dtype: object

# %%
results_num=results.select_dtypes(include=[np.number])
results_cat=results.select_dtypes(include=[bool,object])
print(results_num.head())
print(results_cat.head())
# Out:
#        lr  optimizers  drop  distr  val_loss
# 94  0.001           1   0.5      1  0.108489
# 17  0.010           1   0.2      0  0.115384
# 51  0.010           1   0.2      1  0.119979
# 59  0.010           1   0.2      1  0.120381
# 76  0.001           0   0.5      0  0.125446
#             kernel  use_normalization activation
# 94       he_normal              False       relu
# 17       he_normal               True      swish
# 51  glorot_uniform               True      swish
# 59  glorot_uniform              False      swish
# 76       he_normal              False       relu

# %%
# i need to select the categorical columns, apply the transformation to each column and replace in the initial df
from sklearn.preprocessing import OrdinalEncoder #transforms categorical values in numerical values
ordinal_encoder = OrdinalEncoder()
results_encoded = ordinal_encoder.fit_transform(results_cat)
print("coding: ",ordinal_encoder.categories_)
results_cat=pd.DataFrame(results_encoded,columns=results_cat.columns)
print(results_cat.head())
# Out:
# coding:  [array(['glorot_uniform', 'he_normal'], dtype=object), array([False,  True]), array(['relu', 'swish'], dtype=object)]
#    kernel  use_normalization  activation
# 0     1.0                0.0         0.0
# 1     1.0                1.0         1.0
# 2     0.0                1.0         1.0
# 3     0.0                0.0         1.0
# 4     1.0                0.0         0.0

# %%
results_converted=pd.concat([results_cat,results_num],axis=1)

# %%
print(results_converted.head(5))
# Out:
#    kernel  use_normalization  activation    lr  optimizers  drop  distr  \
# 0     1.0                0.0         0.0  0.01           0   0.2      0
# 1     1.0                1.0         1.0  0.01           0   0.2      0
# 2     0.0                1.0         1.0  0.01           0   0.2      1
# 3     0.0                0.0         1.0  0.01           0   0.2      1
# 4     1.0                0.0         0.0  0.01           0   0.5      0
#
#    val_loss
# 0  0.162042
# 1  0.307463
# 2  0.405418
# 3  1.028196
# 4  0.401054

# %%
#results_converted.hist(bins=50, figsize=(12, 8))
corr_matrix = results_converted.corr()
print(corr_matrix)
# Out:
#                      kernel  use_normalization  activation        lr  \
# kernel             1.000000          -0.047004    0.009393  0.103184
# use_normalization -0.047004           1.000000   -0.008190 -0.150118
# activation         0.009393          -0.008190    1.000000  0.043734
# lr                 0.103184          -0.150118    0.043734  1.000000
# optimizers        -0.137677          -0.159225   -0.043734  0.103774
# drop               0.028186          -0.024576    0.025431  0.028186
# distr              0.078075           0.060252    0.076856  0.009393
# val_loss          -0.079139          -0.116215    0.068403  0.173942
#
#                    optimizers      drop     distr  val_loss
# kernel              -0.137677  0.028186  0.078075 -0.079139
# use_normalization   -0.159225 -0.024576  0.060252 -0.116215
# activation          -0.043734  0.025431  0.076856  0.068403
# lr                   0.103774  0.028186  0.009393  0.173942
# optimizers           1.000000 -0.028186 -0.009393 -0.296198
# drop                -0.028186  1.000000 -0.008769  0.098732
# distr               -0.009393 -0.008769  1.000000  0.132985
# val_loss            -0.296198  0.098732  0.132985  1.000000

# %%
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt

for col in results_converted.columns:
    scatter_matrix(results_converted[["val_loss",col]], figsize=(12, 8))

# %%
for col in results_converted.columns:
    results_converted.plot(x=col,y="val_loss",kind="scatter",s=1)
